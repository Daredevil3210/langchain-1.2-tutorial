# %% [markdown]
# # 自定义中间件-Node-style hooks
# ## 1.基本用法
# ## 1.1基于装饰器的实现

# %%
from langchain.agents.middleware import before_agent, before_model, after_model, after_agent, AgentMiddleware
from typing import Any
from langgraph.runtime import Runtime
from langchain.agents import AgentState

@before_model
def before_model_middleware(state:AgentState,runtime:Runtime)-> dict[str,Any] | None:
    state["messages"][-1].content+="----->before_model<------"
    return None
@after_model
def after_model_middleware(state:AgentState,runtime:Runtime)->dict[str,Any]| None:
    state["messages"][-1].content+="----->after_model<------"
    return None
@before_agent
def before_agent_middleware(state:AgentState,runtime:Runtime)->dict[str,Any]| None:
    state["messages"][-1].content+="----->before_agent<------"
    return None
@after_agent
def after_agent_middleware(state:AgentState,runtime:Runtime)->dict[str,Any]| None:
    state["messages"][-1].content+="----->after_agent<------"
    return None

# %%
import os

from langchain.agents import create_agent
from langchain.agents.middleware import SummarizationMiddleware, PIIMiddleware, TodoListMiddleware
from langchain_core.messages import HumanMessage
from langchain_deepseek import ChatDeepSeek
from dotenv import load_dotenv
from scripts.regsetup import description
from rich import print as rprint
#1.读取.env配置文件信息,相关的环境变量以.env文件中的优先
load_dotenv(verbose=True)
DEEPSEEK_API_KEY=os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL=os.getenv("DEEPSEEK_BASE_URL")
#2.模型初始化
model=ChatDeepSeek(
    model="deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    api_base=DEEPSEEK_BASE_URL,
    # profile={
    #     "max_input_tokens": 1_000_000
    # },
    # 关键修改：关闭思考模式
    extra_body={
        "thinking": {
            "type": "disabled"
        }
    },
)

agent =create_agent(
    model=model,
    middleware=[
        before_model_middleware,
        after_model_middleware,
        before_agent_middleware,
        after_agent_middleware
    ]
)
response=agent.invoke({
    "messages":[HumanMessage("你好")]
})
for msg in response["messages"]:
    msg.pretty_print()
# Out:
# ================================ Human Message =================================
#
# 你好----->before_agent<----------->before_model<------
# ================================== Ai Message ==================================
#
# 你好！很高兴见到你！😊
#
# 我是 DeepSeek，一个乐于助人的 AI 助手。无论你有什么问题、需要什么帮助，或者只是想聊聊天，我都非常乐意陪着你。
#
# 今天有什么我可以帮你的吗？可能是：
# - 回答一些问题
# - 帮你分析某个话题
# - 写作、翻译、编程
# - 或者就是随便聊聊
#
# 尽管告诉我吧，咱们一起解决！🌟----->after_model<----------->after_agent<------

# %% [markdown]
# ### 1.2基于类的实现

# %%
from langchain.agents.middleware import AgentMiddleware
class MyMiddleware(AgentMiddleware):
    def before_model(self,state:AgentState,runtime:Runtime)-> dict[str,Any] | None:
        state["messages"][-1].content+="----->before_model<------"
        return None
    def after_model(self,state:AgentState,runtime:Runtime)->dict[str,Any]| None:
        state["messages"][-1].content+="----->after_model<------"
        return None
    def before_agent(self,state:AgentState,runtime:Runtime)->dict[str,Any]| None:
        state["messages"][-1].content+="----->before_agent<------"
        return None
    def after_agent(self,state:AgentState,runtime:Runtime)->dict[str,Any]| None:
        state["messages"][-1].content+="----->after_agent<------"
        return None

# %%
my_middleware=MyMiddleware()
agent =create_agent(
    model=model,
    middleware=[my_middleware]
)
response=agent.invoke({
    "messages":[HumanMessage("你好")]
})
for msg in response["messages"]:
    msg.pretty_print()
# Out:
# ================================ Human Message =================================
#
# 你好----->before_agent<----------->before_model<------
# ================================== Ai Message ==================================
#
# 你好！😊 很高兴见到你！
#
# 我是DeepSeek，一个乐于助人的AI助手。无论是解答问题、讨论想法、处理文字工作，还是帮你分析信息，我都随时准备好了！
#
# 今天有什么我可以帮你的吗？尽管说，别客气！✨
#
# （遇到复杂的问题也没关系，我们可以一步步来拆解解决。你最近在想些什么呢？）----->after_model<----------->after_agent<------

# %% [markdown]
# ## 2.装饰器参数：can_jump_to
# ### 2.1基于装饰器的实现

# %%
from typing import Any

from langchain.agents import create_agent
from langchain.agents.middleware import before_model, after_model, AgentState
from langchain.messages import AIMessage, SystemMessage
from langchain.tools import tool
from langgraph.runtime import Runtime


@tool
def get_news() -> str:
    """获取当日新闻"""
    return f"美加墨世界杯今日开幕"


# 在模型（LLM）执行前触发。允许跳转到 "tools" 节点。
@before_model(can_jump_to=["tools"])
def force_tool_first(state: AgentState, runtime: Runtime) -> dict[str, Any] | None:
    """
    【业务场景：强行拦截并触发工具】
    如果用户输入包含 "direct tool"，则跳过本次大模型的思考/生成阶段，
    直接伪造一个大模型的 tool_calls 意图，强行把控制权移交给工具执行节点。
    """
    text = state["messages"][-1].content
    # 检查关键词，满足条件则强行干预流程
    if isinstance(text, str) and "direct tool" in text.lower():
        print("[MIDDLEWARE] before_model: jump_to='tools'")

        # 人工构造一个大模型的消息对象（AIMessage）
        # 欺骗系统，让系统误以为这是模型自己决定要调用的工具
        fake_tool_call = AIMessage(
            content="人工构造的消息",
            tool_calls=[
                {
                    "name": "get_news",
                    "args": {},
                    "id": "call_force_weather_001",
                }
            ],
        )

        # 返回更新后的状态：注入伪造的消息，并明确指定下一步跳转到 "tools" 节点
        return {
            "messages": [fake_tool_call],
            "jump_to": "tools",
        }
    # 如果不满足触发条件，返回 None，流程正常向下流转（继续让 LLM 思考）
    return None

# # 在模型（LLM）执行生成之后触发。允许重新跳转回 "model" 节点。
# @after_model(can_jump_to=["model"])
# def retry_with_extra_instruction(state: AgentState, runtime: Runtime) -> dict[str, Any] | None:
#     """
#     【业务场景：反思/重试机制】
#     如果大模型已经生成了回答，但发现用户最初的请求包含 "retry model"，
#     则动态追加一条系统提示词（SystemMessage），强行让模型重新生成（重试）一次。
#     """
#     # 倒序遍历消息历史，找到最近的一次用户输入（human 消息）
#     user_text = ""
#     for msg in reversed(state["messages"]):
#         if getattr(msg, "type", "") == "human":
#             user_text = getattr(msg, "content", "")
#             break
#
#     # 检查用户输入是否包含触发重试的关键字
#     if isinstance(user_text, str) and "retry model" in user_text.lower():
#         # 【核心防御】：防止无限循环重跳（死循环）
#         # 检查消息历史中是否已经注入过这条特殊的系统提示。如果有，说明已经重试过了，不再重复干预。
#         already_injected = any(
#             isinstance(getattr(msg, "content", None), str)
#             and "你必须以【二次回答】开头" in msg.content
#             for msg in state["messages"]
#         )
#         if already_injected:
#             return None # 已注入过，直接放行，结束重试流程
#
#         print("[MIDDLEWARE] after_model: jump_to='model' with extra system instruction")
#
#         # 返回更新后的状态：追加强力约束的系统消息，并将指针跳回 "model" 节点重新执行
#         return {
#             "messages": [
#                 SystemMessage("你必须以【二次回答】开头，并且只用一句话回答。")
#             ],
#             "jump_to": "model",
#         }
#
#     return None




from langchain_core.messages import AIMessage


@after_model(can_jump_to=["model"])
def retry_with_extra_instruction(
    state: AgentState,
    runtime: Runtime,
) -> dict[str, Any] | None:

    user_text = ""

    for msg in reversed(state["messages"]):
        if getattr(msg, "type", "") == "human":
            user_text = getattr(msg, "content", "")
            break

    if not (
        isinstance(user_text, str)
        and "retry model" in user_text.lower()
    ):
        return None

    # 如果模型请求调用工具，不能跳过 tools 节点
    last_message = state["messages"][-1]

    if isinstance(last_message, AIMessage) and last_message.tool_calls:
        return None

    # 防止重复重试
    already_injected = any(
        isinstance(getattr(msg, "content", None), str)
        and "你必须以【二次回答】开头" in msg.content
        for msg in state["messages"]
    )

    if already_injected:
        return None

    print("触发模型重试")

    return {
        "messages": [
            SystemMessage(
                content="你必须以【二次回答】开头，并且只用一句话回答。"
            )
        ],
        "jump_to": "model",
    }





# 在模型（LLM）执行前触发。允许直接跳转到 "end" 节点（强行终止）。
@before_model(can_jump_to=["end"])
def overflow_context_processor(state: AgentState, runtime: Runtime) -> dict[str, Any] | None:
    """
    【业务场景：安全卫士/异常拦截】
    模拟上下文窗口溢出（Token超限）或其他严重的系统阻断情况。
    一旦触发，直接熔断流程，拒绝让大模型继续处理，直接报错或返回兜底文案。
    """

    # 假装溢出,模拟检查最后一条消息是否包含 overflow 标识
    if "overflow" in state["messages"][-1].content:
        print("[MIDDLEWARE] before_model: jump_to='end' when contenxt window overflow")

        # 构造兜底的结束消息，并直接指定跳转到 "end" 终止 Agent 运行
        return {
            "messages": [
                AIMessage("上下文窗口溢出，终止")
            ],
            "jump_to": "end",
        }


agent = create_agent(
    model=model,
    tools=[get_news],
    # # 将定义的中间件按照顺序挂载到 Agent 中（注意：执行顺序会严格按照列表声明顺序）
    middleware=[force_tool_first, retry_with_extra_instruction, overflow_context_processor],
)


def run_once(user_input: str):
    result = agent.invoke(
        {
            "messages": [
                {"role": "user", "content": user_input}
            ]
        }
    )

    for msg in result["messages"]:
        msg.pretty_print()


if __name__ == "__main__":
    # Case 1: 直接跳 tools
    # 预期表现：
    # 1. 触发 force_tool_first，打印 "[MIDDLEWARE] before_model: jump_to='tools'"
    # 2. 绕过 LLM 的首轮思考，直接调用 `get_news` 工具
    # 3. 工具返回结果后，LLM 总结工具结果并输出
    print('=' * 30, '-> Case 1 <-', '=' * 30)
    run_once("请帮我查今日新闻 direct tool")

    # Case 2: 输出后跳回 model
    # 预期表现：
    # 1. 正常进入 LLM 生成第 1 版回答
    # 2. 触发 retry_with_extra_instruction，打印 "[MIDDLEWARE] after_model: jump_to='model'..."
    # 3. 注入系统提示词后，LLM 被强行拉回并生成第 2 版回答
    # 4. 最终输出应带有“【二次回答】”前缀
    print('=' * 30, '-> Case 2 <-', '=' * 30)
    run_once("请随便介绍一下 LangChain retry model")

    # Case 3:
    # 预期表现：
    # 1. 触发 overflow_context_processor 中间件
    # 2. 直接打印终止信息并退出，LLM 根本不会接收到这个请求
    print('=' * 30, '-> Case 3 <-', '=' * 30)
    run_once("你好 overflow")

    # Case 4: 正常流程
    # 预期表现：
    # 1. 没有任何中间件被触发（不满足任何关键字）
    # 2. Agent 走正常的 OOTB（Out of the box）标准工作流：User -> Model -> Call Tool -> Model -> End
    print('=' * 30, '-> Case 4 <-', '=' * 30)
    run_once("今日新闻摘要？")
# Out:
# ============================== -> Case 1 <- ==============================
# [MIDDLEWARE] before_model: jump_to='tools'
# ================================ Human Message =================================
#
# 请帮我查今日新闻 direct tool
# ================================== Ai Message ==================================
#
# 人工构造的消息
# Tool Calls:
#   get_news (call_force_weather_001)
#  Call ID: call_force_weather_001
#   Args:
# ================================= Tool Message =================================
# Name: get_news
#
# 美加墨世界杯今日开幕
# ================================== Ai Message ==================================
#
# 根据查询，今日的新闻是：
#
# **美加墨世界杯今日开幕**
#
# 如需查看更多新闻，请随时告诉我。
# ============================== -> Case 2 <- ==============================
# 触发模型重试
# ================================ Human Message =================================
#
# 请随便介绍一下 LangChain retry model
# ================================== Ai Message ==================================
#
# 我来先获取一下当日新闻，看看有没有相关信息。
# Tool Calls:
#   get_news (call_00_Q2HKn9fdXA7VswAKGBWw4081)
#  Call ID: call_00_Q2HKn9fdXA7VswAKGBWw4081
#   Args:
# ================================= Tool Message =================================
# Name: get_news
#
# 美加墨世界杯今日开幕
# ================================== Ai Message ==================================
#
# 让我来为你介绍 LangChain 中的 **Retry Model（重试模型）**。
#
# ## 什么是 Retry 模型
#
# LangChain 中的 Retry 机制主要用于处理 **LLM 调用过程中的临时性错误**，例如网络超时、服务限流（rate limit）、瞬时过载等。当遇到这类可重试的错误时，会自动重新发起请求，而不是直接让整个调用失败。
#
# ## 核心组件
#
# LangChain 提供了几个与重试相关的关键组件：
#
# ### 1. `with_retry()` 方法
# 这是最常用的方式，几乎所有链组件（LLM、Chain 等）都支持：
#
# ```python
# from langchain_anthropic import ChatAnthropic
#
# llm = ChatAnthropic(
#     model="claude-3-5-sonnet",
#     max_retries=3,  # 直接设置重试次数
#     timeout=60
# )
# ```
#
# ### 2. `RetryChain`（更灵活的重试）
# LangChain 提供了 `RetryChain` 和 `RetryWithErrorChain` 来包裹链，让你能对重试逻辑做更精细的控制：
#
# ```python
# from langchain.chains import RetryChain
# from langchain.chains.retry import RetryWithErrorChain
#
# chain = prompt | llm | output_parser
#
# retry_chain = RetryWithErrorChain.from_llm(
#     llm=llm,  # 用于分析错误的重试 LLM
# )
# ```
#
# **关键区别：**
# - **普通重试**：简单地重新调用原 LLM
# - **智能重试**（`RetryWithErrorChain`）：把上次的错误信息作为上下文，让 LLM 分析错误原因后有针对性地重新生成
#
# ### 3. 参数配置
# 常见可配置参数：
# - `max_retries`：最大重试次数
# - `retry_if_exception_type`：指定哪些异常类型才触发重试（默认通常只重试可恢复的异常）
# - `exponential_backoff` / `retry_on_timeout`：指数退避策略，避免雪崩式重试
#
# ## 实际使用示例
#
# ```python
# from langchain_openai import ChatOpenAI
# from tenacity import retry, stop_after_attempt, wait_exponential
#
# # 方法一：LangChain 内置
# llm = ChatOpenAI(model="gpt-4", max_retries=5)
#
# # 方法二：配合 tenacity 库做更精细控制
# @retry(
#     wait=wait_exponential(multiplier=1, min=2, max=60),
#     stop=stop_after_attempt(6)
# )
# def call_llm(prompt):
#     return llm.invoke(prompt)
# ```
#
# ## 使用建议
#
# 1. **区分错误类型**：只在遇到临时性错误（如 429 限流、超时、网络波动）时才重试，避免对参数错误、API key 无效等永久性错误无限重试
# 2. **设置合理次数**：不要无限重试，通常 3-6 次比较合适
# 3. **配合退避策略**：使用指数退避 + 随机抖动，防止在服务恢复瞬间所有请求同时涌入造成雪崩
# 4. **考虑重试的幂等性**：确保重复调用不会产生副作用（如重复扣费、重复写入）
#
# ---
#
# 顺便提一句，今天的新闻提到 **美加墨世界杯今日开幕** ⚽！这算是相关话题吗？如果你是想问和"重试模型"有关的世界杯预测问题，或者有其他具体场景想深入了解重试机制，欢迎告诉我！
# ================================ System Message ================================
#
# 你必须以【二次回答】开头，并且只用一句话回答。
# ================================== Ai Message ==================================
#
# 二次回答：以上是关于 LangChain Retry 模型的全面介绍，涵盖内置的重试机制、智能重试链以及配合 tenacity 库的进阶用法。
# ============================== -> Case 3 <- ==============================
# [MIDDLEWARE] before_model: jump_to='end' when contenxt window overflow
# ================================ Human Message =================================
#
# 你好 overflow
# ================================== Ai Message ==================================
#
# 上下文窗口溢出，终止
# ============================== -> Case 4 <- ==============================
# ================================ Human Message =================================
#
# 今日新闻摘要？
# ================================== Ai Message ==================================
#
# 我来帮你获取今日的新闻摘要。
# Tool Calls:
#   get_news (call_00_d3DVUGc9K9rjMiGk43041208)
#  Call ID: call_00_d3DVUGc9K9rjMiGk43041208
#   Args:
# ================================= Tool Message =================================
# Name: get_news
#
# 美加墨世界杯今日开幕
# ================================== Ai Message ==================================
#
# 根据今日新闻，为你提供以下摘要：
#
# **今日头条新闻：美加墨世界杯今日开幕**
#
# 2026年美加墨世界杯今天正式开幕！这是世界杯历史上首次由三个国家（美国、加拿大、墨西哥）联合举办，也是参赛球队数量扩军至48队的首届世界杯，备受全球瞩目。
#
# ---
#
# 如果需要我对这条新闻进行更详细的解读，或者想了解其他方面的信息，随时告诉我！⚽

# %% [markdown]
# ### 2.2基于类的实现

# %%
from typing import Any

from langchain.agents import create_agent
from langchain.agents.middleware import hook_config, AgentState, AgentMiddleware
from langchain.messages import AIMessage, SystemMessage
from langchain.tools import tool
from langgraph.runtime import Runtime


@tool
def get_news() -> str:
    """获取当日新闻"""
    return f"美加墨世界杯今日开幕"


class MyMiddleware(AgentMiddleware):
    @hook_config(can_jump_to=["tools", "end"])
    def before_model(self, state: AgentState, runtime: Runtime) -> dict[str, Any] | None:
        text = state["messages"][-1].content
        # 假装溢出
        if "overflow" in text:
            print("[MIDDLEWARE] before_model: jump_to='end' when contenxt window overflow")
            return {
                "messages": [
                    AIMessage("上下文窗口溢出，终止")
                ],
                "jump_to": "end",
            }

        if isinstance(text, str) and "direct tool" in text.lower():
            print("[MIDDLEWARE] before_model: jump_to='tools'")

            fake_tool_call = AIMessage(
                content="人工构造的消息",
                tool_calls=[
                    {
                        "name": "get_news",
                        "args": {},
                        "id": "call_force_weather_001",
                    }
                ],
            )

            return {
                "messages": [fake_tool_call],
                "jump_to": "tools",
            }

        return None

    # @hook_config(can_jump_to=["model"])
    # def after_model(self, state: AgentState, runtime: Runtime) -> dict[str, Any] | None:
    #     user_text = ""
    #     for msg in reversed(state["messages"]):
    #         if getattr(msg, "type", "") == "human":
    #             user_text = getattr(msg, "content", "")
    #             break
    #
    #     if isinstance(user_text, str) and "retry model" in user_text.lower():
    #         # 防止无限重跳：如果已经加过提示，就不再跳
    #         already_injected = any(
    #             isinstance(getattr(msg, "content", None), str)
    #             and "你必须以【二次回答】开头" in msg.content
    #             for msg in state["messages"]
    #         )
    #         if already_injected:
    #             return None
    #
    #         print("[MIDDLEWARE] after_model: jump_to='model' with extra system instruction")
    #
    #         return {
    #             "messages": [
    #                 SystemMessage("你必须以【二次回答】开头，并且只用一句话回答。")
    #             ],
    #             "jump_to": "model",
    #         }
    #
    #     return None



@hook_config(can_jump_to=["model"])
def after_model(
    self,
    state: AgentState,
    runtime: Runtime,
) -> dict[str, Any] | None:

    user_text = ""

    for msg in reversed(state["messages"]):
        if getattr(msg, "type", "") == "human":
            user_text = getattr(msg, "content", "")
            break

    if not (
        isinstance(user_text, str)
        and "retry model" in user_text.lower()
    ):
        return None

    # 关键：如果模型请求了工具，先让工具正常执行
    last_message = state["messages"][-1]

    if isinstance(last_message, AIMessage) and last_message.tool_calls:
        print("[MIDDLEWARE] 检测到工具调用，先执行工具")
        return None

    already_injected = any(
        isinstance(getattr(msg, "content", None), str)
        and "你必须以【二次回答】开头" in msg.content
        for msg in state["messages"]
    )

    if already_injected:
        return None

    print("[MIDDLEWARE] 重试模型")

    return {
        "messages": [
            SystemMessage(
                content="你必须以【二次回答】开头，并且只用一句话回答。"
            )
        ],
        "jump_to": "model",
    }





agent = create_agent(
    model=model,
    tools=[get_news],
    middleware=[MyMiddleware()],
)


def run_once(user_input: str):
    result = agent.invoke(
        {
            "messages": [
                {"role": "user", "content": user_input}
            ]
        }
    )

    for msg in result["messages"]:
        msg.pretty_print()


if __name__ == "__main__":
    # Case 1: 直接跳 tools
    print('=' * 30, '-> Case 1 <-', '=' * 30)
    run_once("请帮我查今日新闻 direct tool")

    # Case 2: 输出后跳回 model
    print('=' * 30, '-> Case 2 <-', '=' * 30)
    run_once("请随便介绍一下 LangChain retry model")

    # Case 3:
    print('=' * 30, '-> Case 3 <-', '=' * 30)
    run_once("你好 overflow")

    # Case 4: 正常流程
    print('=' * 30, '-> Case 4 <-', '=' * 30)
    run_once("今日新闻摘要？")
# Out:
# ============================== -> Case 1 <- ==============================
# [MIDDLEWARE] before_model: jump_to='tools'
# ================================ Human Message =================================
#
# 请帮我查今日新闻 direct tool
# ================================== Ai Message ==================================
#
# 人工构造的消息
# Tool Calls:
#   get_news (call_force_weather_001)
#  Call ID: call_force_weather_001
#   Args:
# ================================= Tool Message =================================
# Name: get_news
#
# 美加墨世界杯今日开幕
# ================================== Ai Message ==================================
#
# 今日新闻：**美加墨世界杯今日开幕** ⚽
# ============================== -> Case 2 <- ==============================
# ================================ Human Message =================================
#
# 请随便介绍一下 LangChain retry model
# ================================== Ai Message ==================================
# Tool Calls:
#   get_news (call_00_qYhImN4kWbITOnKw4hO29846)
#  Call ID: call_00_qYhImN4kWbITOnKw4hO29846
#   Args:
# ================================= Tool Message =================================
# Name: get_news
#
# 美加墨世界杯今日开幕
# ================================== Ai Message ==================================
#
# 好的，让我来介绍一下 **LangChain 中的 Retry Model**（重试模型）。
#
# ---
#
# ## 什么是 LangChain Retry Model？
#
# LangChain 的 **Retry 模型** 是一种用于提高 LLM（大语言模型）调用可靠性的机制。在实际应用中，调用 LLM API 时可能会遇到各种问题，比如：
#
# - 网络波动导致的超时
# - API 限流（Rate Limit）
# - 临时性服务器错误（5xx）
# - 返回格式不符合预期
#
# **Retry（重试）模型** 的核心思想是：当一次调用失败时，自动重新发起请求，直到成功或达到最大重试次数。
#
# ---
#
# ## 主要实现方式
#
# ### 1. 基础重试（Basic Retry）
#
# 最简单的形式，在调用 LLM 失败时按一定策略重试：
#
# ```python
# from langchain.llms import OpenAI
# from tenacity import retry, stop_after_attempt, wait_exponential
#
# llm = OpenAI(model="gpt-4")
#
# @retry(
#     stop=stop_after_attempt(3),          # 最多重试3次
#     wait=wait_exponential(multiplier=1, min=2, max=30)  # 指数退避等待
# )
# def call_with_retry(prompt):
#     return llm(prompt)
# ```
#
# ### 2. 使用 LangChain 内置的 Retry
#
# LangChain 本身也提供了重试相关的工具，常见的是结合 **`RetryWithError`** 或通过自定义的回调来处理。
#
# ### 3. 结合 LangSmith / Callback 的重试
#
# 利用 LangChain 的回调机制，在异常时触发重试逻辑：
#
# ```python
# from langchain.callbacks import CallbackManager
# from langchain.callbacks.base import BaseCallbackHandler
#
# class RetryCallback(BaseCallbackHandler):
#     def on_llm_error(self, error, **kwargs):
#         # 在出错时执行重试逻辑
#         print(f"LLM 调用出错: {error}，准备重试...")
# ```
#
# ---
#
# ## 常用的重试策略
#
# | 策略 | 说明 |
# |------|------|
# | **固定间隔重试** | 每次重试前等待固定的时间 |
# | **指数退避（Exponential Backoff）** | 重试间隔随次数指数增长（如 1s → 2s → 4s → 8s） |
# | **随机抖动（Jitter）** | 在退避时间上增加随机性，避免多个请求同时重试造成雪崩 |
# | **根据错误类型重试** | 只对特定错误（如超时、限流）重试，其他错误直接放弃 |
#
# ---
#
# ## 为什么重要？
#
# - **提高稳定性**：LLM API 经常不稳定，重试能显著提升调用的成功率。
# - **节省成本**：配合指数退避，避免因频繁重试导致 API 费用飙升。
# - **生产环境必备**：在构建实际部署的 Agent 或 Chatbot 时，重试机制几乎是标配。
#
# ---
#
# ## 简单示例：完整重试逻辑
#
# ```python
# from tenacity import (
#     retry,
#     stop_after_attempt,
#     wait_random_exponential,
#     retry_if_exception_type
# )
# from langchain.llms import OpenAI
# import openai
#
# llm = OpenAI()
#
# @retry(
#     retry=retry_if_exception_type((
#         openai.APIError,          # API 错误
#         openai.APITimeoutError,   # 超时
#         openai.RateLimitError,    # 限流
#     )),
#     wait=wait_random_exponential(multiplier=1, max=60),
#     stop=stop_after_attempt(5),
# )
# def robust_llm_call(prompt: str) -> str:
#     return llm(prompt)
#
# # 使用
# result = robust_llm_call("介绍一下人工智能")
# print(result)
# ```
#
# ---
#
# ## 总结
#
# LangChain 的 Retry Model 本质上是一层"可靠性包装"，它让 LLM 调用在面对临时性故障时能够自动恢复，从而保证你的应用在真实生产环境中更加稳定、可靠。配合 `tenacity` 等 Python 库，可以非常灵活地配置重试次数、等待策略和错误过滤条件。
#
# ---
#
# 顺带一提，刚才获取到的今日新闻是 **"美加墨世界杯今日开幕"**，这和我们讨论的 LangChain 没有直接关系，但如果你有兴趣，我也可以聊聊相关内容 😄 有什么其他想深入了解的吗？
# ============================== -> Case 3 <- ==============================
# [MIDDLEWARE] before_model: jump_to='end' when contenxt window overflow
# ================================ Human Message =================================
#
# 你好 overflow
# ================================== Ai Message ==================================
#
# 上下文窗口溢出，终止
# ============================== -> Case 4 <- ==============================
# ================================ Human Message =================================
#
# 今日新闻摘要？
# ================================== Ai Message ==================================
#
# 我来为您获取今日的新闻摘要。
# Tool Calls:
#   get_news (call_00_ygT6zbggXdVVyKTX8v255783)
#  Call ID: call_00_ygT6zbggXdVVyKTX8v255783
#   Args:
# ================================= Tool Message =================================
# Name: get_news
#
# 美加墨世界杯今日开幕
# ================================== Ai Message ==================================
#
# 根据获取到的今日新闻，为您提供以下摘要：
#
# **📰 今日头条新闻：**
#
# **美加墨世界杯今日开幕**
# - 2026年美加墨世界杯（美国、加拿大、墨西哥联合举办）于今日正式开幕。
# - 这是世界杯历史上首次由三个国家联合举办，也是参赛队伍扩军至48队后的首届赛事。
#
# ---
#
# 很抱歉，目前只获取到这一条今日新闻。如果您想了解更多特定领域（如财经、科技、体育等）的新闻，或者有其他问题需要帮助，请随时告诉我！😊
