# %%
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
from langchain_community.chat_models import ChatZhipuAI

#调用线上大模型
##1.调用具体厂商的api
###1.1调用ds
#举例1:将参数信息存储在.env配置文件中

# %%
import os
from langchain_deepseek import ChatDeepSeek
from dotenv import load_dotenv
#1.读取.env配置文件信息,相关的环境变量以.env文件中的优先
load_dotenv(verbose=True)
DEEPSEEK_API_KEY=os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL=os.getenv("DEEPSEEK_BASE_URL")
#2.模型初始化
llm_deepseek=ChatDeepSeek(
    model="deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    api_base=DEEPSEEK_BASE_URL
)
#3.模型调用
response=llm_deepseek.invoke("请用一句话介绍你自己")
print(response)

# %% [markdown]
# 举例2是对举例1的优化

# %%
import os
from langchain_deepseek import ChatDeepSeek
from dotenv import load_dotenv
#1.读取.env配置文件信息,相关的环境变量以.env文件中的优先
load_dotenv(verbose=True)
# DEEPSEEK_API_KEY=os.getenv("DEEPSEEK_API_KEY")
# DEEPSEEK_BASE_URL=os.getenv("DEEPSEEK_BASE_URL")
#2.模型初始化
llm_deepseek=ChatDeepSeek(
    model="deepseek-v4-flash",
    # api_key=DEEPSEEK_API_KEY,
    # api_base=DEEPSEEK_BASE_URL
)
#3.模型调用
response=llm_deepseek.invoke("请用一句话介绍你自己")
print(response)

# %% [markdown]
# 举例3：参数声明在代码中

# %%
import os
from langchain_deepseek import ChatDeepSeek
from dotenv import load_dotenv
#1.读取.env配置文件信息,相关的环境变量以.env文件中的优先
load_dotenv()

#2.模型初始化
llm_deepseek=ChatDeepSeek(
    model="deepseek-v4-flash",
    api_key=os.getenv("DEEPSEEK_API_KEY"),
    api_base="https://api.deepseek.com"
)
#3.模型调用
response=llm_deepseek.invoke("请用一句话介绍你自己")
print(response)

# %% [markdown]
# 1.2调用智谱

# %%
import os
from langchain_community.chat_models import ChatZhipuAI
from dotenv import load_dotenv
#1.读取.env配置文件信息,相关的环境变量以.env文件中的优先
load_dotenv(verbose=True)
ZHIPU_API_KEY=os.getenv("ZHIPU_API_KEY")
ZHIPU_BASE_URL=os.getenv("ZHIPU_BASE_URL")
#2.模型初始化
llm_zhipu=ChatZhipuAI(
    model="glm-5.3",
    api_key=ZHIPU_API_KEY,
    api_base=ZHIPU_BASE_URL
)
#3.模型调用
response=llm_zhipu.invoke("请用一句话介绍你自己")
print(response)

# %% [markdown]
# ##2.兼容的写法
# 使用ChatOpenI
# 举例1：调用ds

# %%
from langchain_openai import ChatOpenAI
import os
from dotenv import load_dotenv
load_dotenv(override=True)


DEEPSEEK_API_KEY=os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL=os.getenv("DEEPSEEK_BASE_URL")
model=ChatOpenAI(
    model="deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL
)
print(model.invoke("1+1=?"))

# %% [markdown]
# 举例2：调用质谱

# %%
from langchain_openai import ChatOpenAI
import os
from dotenv import load_dotenv
load_dotenv(override=True)


ZHIPU_API_KEY=os.getenv("ZHIPU_API_KEY")
ZHIPU_BASE_URL=os.getenv("ZHIPU_BASE_URL")
model=ChatOpenAI(
    model="glm-5.3",
    api_key=ZHIPU_API_KEY,
    base_url=ZHIPU_BASE_URL
)
print(model.invoke("1+1=?"))

# %% [markdown]
# ## 3.使用中转平台
# ###3.1 使用OpenRouter

# %%
from langchain_openrouter import ChatOpenRouter
from langchain_openai import ChatOpenAI
import os
from dotenv import load_dotenv
load_dotenv(override=True)


OPENROUTER_API_KEY=os.getenv("OPENROUTER_API_KEY")
OPENROUTER_API_BASE=os.getenv("OPENROUTER_API_BASE")
model=ChatOpenRouter(
    model="openai/gpt-5.6-luna",
    api_key=OPENROUTER_API_KEY,
    base_url=OPENROUTER_API_BASE
)
print(model.invoke("一句话介绍一下你自己"))

# %% [markdown]
# ## 4.使用langchain1.xd的统一方式
# 使用 init_chat_model()
# 举例1：调用ds官网ds模型

# %%
import os
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
#1.读取.env配置文件信息,相关的环境变量以.env文件中的优先
load_dotenv(verbose=True)
DEEPSEEK_API_KEY=os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL=os.getenv("DEEPSEEK_BASE_URL")
#2.模型初始化
model=init_chat_model(
    # model="deepseek-v4-flash",
    # model_provider="deepseek",
    model="deepseek:deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL
)
#3.模型调用
response=model.invoke("请用一句话介绍你自己")
print(response)

# %% [markdown]
# ## 5.小结
# ds官网的ds模型:ChatDeepSeek(),ChatOpenAI(),init_chat_model()
# 阿里云百炼平台的ds模型ChatTongYi(),ChatOpenAI(),init_chat_model()
# openrouter平台的ds模型ChatOpenRouter(),ChatOpenAI(),init_chat_model()
# closeai平台的ds模型ChatOpenAI(),init_chat_model()
